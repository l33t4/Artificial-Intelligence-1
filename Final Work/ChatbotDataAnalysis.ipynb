# %%
import pandas as pd 
import csv

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

f=open('/content/gdrive/My Drive/MachineLearning/Book1.csv','r',errors = 'ignore')#this opens a text file from google drive which could be used for the corpus of questions

raw=f.read()

datar = csv.reader(open('/content/gdrive/My Drive/MachineLearning/Book1.csv', 'r', encoding='utf-8-sig'))

df = pd.read_csv('/content/gdrive/My Drive/MachineLearning/Book1.csv')

df['Target'].value_counts().plot(kind="bar", figsize=(15,7), color="#61d199", title = "Total Targets Met")
# Out:
# Mounted at /content/gdrive
